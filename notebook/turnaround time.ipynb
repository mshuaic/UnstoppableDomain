# %%
import pandas as pd

# %%
df = pd.read_csv("../data/elapsed/all.csv")

# %%
df
# Out:
#                                domain  remote name resolution  \
# 0                      givenow.crypto                0.153166
# 1     123412341234123412341234.crypto                0.134568
# 2           reseller-test-don9.crypto                0.131959
# 3           reseller-test-don7.crypto                0.156709
# 4                   addictedto.crypto                0.172368
# ...                               ...                     ...
# 4897              sweetbabygus.crypto                0.127003
# 4898                giozaarour.crypto                0.131564
# 4899            hermetic-world.crypto                0.153779
# 4900              playboymeech.crypto                0.133209
# 4901                    tacoin.crypto                0.085084
#
#       local name resolution_remote rpc  local name resolution_local rpc  \
# 0                             0.179853                         0.033524
# 1                             0.050880                         0.025179
# ...

# %%
df.describe()
# Out:
#        remote name resolution  local name resolution_remote rpc  \
# count             4902.000000                       4902.000000
# mean                 0.110107                          0.045530
# std                  0.084027                          0.096997
# min                 -1.000000                         -1.000000
# 25%                  0.084772                          0.047250
# 50%                  0.123230                          0.048942
# 75%                  0.132135                          0.051300
# max                  1.572738                          0.620818
#
#        local name resolution_local rpc  remote ipfs gateway  \
# count                      4902.000000          4902.000000
# mean                          0.016621             0.687202
# std                           0.092233             1.070938
# min                          -1.000000            -1.000000
# 25%                           0.016326             0.440987
# ...

# %%
import numpy as np
a = df.replace(to_replace=-1, value=np.nan)

# %%
top100 = pd.read_csv("../data/top100_elaspsed.csv", names=["domain", "RT"])

# %%
top100.replace(to_replace=-1, value=np.nan).describe()
# Out:
#               RT
# count  92.000000
# mean    0.686767
# std     0.814786
# min     0.024625
# 25%     0.145446
# 50%     0.331322
# 75%     1.038600
# max     4.650622
